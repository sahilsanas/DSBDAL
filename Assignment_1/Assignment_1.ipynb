# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Assignment_1/melb_data.csv")

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df.shape
# Out:
# (13580, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# **Statistical Summary**

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %% [markdown]
# **List the datatypes in the dataset**

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %% [markdown]
# **Converting Data to Correct datatype**

# %%
df["Date"] = pd.to_datetime(df["Date"], dayfirst = True)

# %%
df["Postcode"] = df["Postcode"].astype(str)

# %% [markdown]
# **Fill missing values of numeric values with mean**

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns

# %%
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# %% [markdown]
# **Fill missing values of categorical values with mode**

# %%
df["CouncilArea"] = df["CouncilArea"].fillna(df["CouncilArea"].mode()[0])

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
scaler = StandardScaler()

df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
df.head()
# Out:
#        Suburb           Address     Rooms Type     Price Method SellerG  \
# 0  Abbotsford      85 Turner St -0.981463    h  0.632448      S  Biggin
# 1  Abbotsford   25 Bloomburg St -0.981463    h -0.063640      S  Biggin
# 2  Abbotsford      5 Charles St  0.064876    h  0.608984     SP  Biggin
# 3  Abbotsford  40 Federation La  0.064876    h -0.353025     PI  Biggin
# 4  Abbotsford       55a Park St  1.111216    h  0.820157     VB  Nelson
#
#         Date  Distance Postcode  ...  Bathroom       Car  Landsize  \
# 0 2016-12-03 -1.301485   3067.0  ... -0.772376 -0.635232 -0.089316
# 1 2016-02-04 -1.301485   3067.0  ... -0.772376 -1.676467 -0.100843
# 2 2017-03-04 -1.301485   3067.0  ...  0.673367 -1.676467 -0.106356
# 3 2017-03-04 -1.301485   3067.0  ...  0.673367 -0.635232 -0.116380
# 4 2016-06-04 -1.301485   3067.0  ... -0.772376  0.406003 -0.109864
#
#    BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0      0.000000   0.000000        Yarra  0.121160    0.030640
# ...

# %%
categorical_cols = df.select_dtypes(include=["object"]).columns

encoder = LabelEncoder()
for col in categorical_cols:
    df[col] = encoder.fit_transform(df[col])

# %%
df.head()
# Out:
#    Suburb  Address     Rooms  Type     Price  Method  SellerG       Date  \
# 0       0    12794 -0.981463     0  0.632448       1       23 2016-12-03
# 1       0     5943 -0.981463     0 -0.063640       1       23 2016-02-04
# 2       0     9814  0.064876     0  0.608984       3       23 2017-03-04
# 3       0     9004  0.064876     0 -0.353025       0       23 2017-03-04
# 4       0    10589  1.111216     0  0.820157       4      155 2016-06-04
#
#    Distance  Postcode  ...  Bathroom       Car  Landsize  BuildingArea  \
# 0 -1.301485        53  ... -0.772376 -0.635232 -0.089316      0.000000
# 1 -1.301485        53  ... -0.772376 -1.676467 -0.100843     -0.186147
# 2 -1.301485        53  ...  0.673367 -1.676467 -0.106356     -0.005020
# 3 -1.301485        53  ...  0.673367 -0.635232 -0.116380      0.000000
# 4 -1.301485        53  ... -0.772376  0.406003 -0.109864     -0.025428
#
#    YearBuilt  CouncilArea  Lattitude  Longtitude  Regionname  Propertycount
# ...

# %%
df.dtypes
# Out:
# Suburb                    int64
# Address                   int64
# Rooms                   float64
# Type                      int64
# Price                   float64
# Method                    int64
# SellerG                   int64
# Date             datetime64[ns]
# Distance                float64
# Postcode                  int64
# Bedroom2                float64
# Bathroom                float64
# Car                     float64
# Landsize                float64
# BuildingArea            float64
# YearBuilt               float64
# CouncilArea               int64
# Lattitude               float64
# Longtitude              float64
# Regionname                int64
# Propertycount           float64
# dtype: object

# %% [markdown]
# # Task
# The dataset has undergone the following transformations:
#
# *   **Normalization**: Numeric columns (`Rooms`, `Price`, `Distance`, `Bedroom2`, `Bathroom`, `Car`, `Landsize`, `BuildingArea`, `YearBuilt`, `Lattitude`, `Longtitude`, `Propertycount`) have been normalized using `StandardScaler`.
# *   **Categorical Encoding**: Categorical columns (`Suburb`, `Address`, `Type`, `Method`, `SellerG`, `Postcode`, `CouncilArea`, `Regionname`) have been transformed into numerical representations using `LabelEncoder`. The `Date` column was also converted to `datetime` objects and `Postcode` to string before encoding.
#
# Here's a glimpse of the DataFrame after these transformations:
#
# ```
#      Suburb  Address     Rooms  Type     Price  Method  SellerG       Date  \
# 0       0    12794 -0.981463     0  0.632448       1       23 2016-12-03
# 1       0     5943 -0.981463     0 -0.063640       1       23 2016-02-04
# 2       0     9814  0.064876     0  0.608984       3       23 2017-03-04
# 3       0     9004  0.064876     0 -0.353025       0       23 2017-03-04
# 4       0    10589  1.111216     0  0.820157       4      155 2016-06-04
#
#    Distance  Postcode  ...  Bathroom       Car  Landsize  BuildingArea  \
# 0 -1.301485        53  ... -0.772376 -0.635232 -0.089316      0.000000
# 1 -1.301485        53  ... -0.772376 -1.676467 -0.100843     -0.186147
# 2 -1.301485        53  ...  0.673367 -1.676467 -0.106356     -0.005020
# 3 -1.301485        53  ...  0.673367 -0.635232 -0.116380      0.000000
# 4 -1.301485        53  ... -0.772376  0.406003 -0.109864     -0.025428
#
#    YearBuilt  CouncilArea  Lattitude  Longtitude  Regionname  Propertycount
# 0   0.000000           31   0.121160    0.030640           2      -0.784625
# 1  -2.232709           31   0.016437   -0.017478           2      -0.784625
# 2  -2.232709           31  -0.001227   -0.007855           2      -0.784625
# 3   0.000000           31   0.155226    0.016204           2      -0.784625
# 4   1.702236           31   0.025269   -0.010742           2      -0.784625
# ```
#
# And the updated data types are:
#
# ```
# Suburb                      int64
# Address                     int64
# Rooms                     float64
# Type                        int64
# Price                     float64
# Method                      int64
# SellerG                     int64
# Date               datetime64[ns]
# Distance                  float64
# Postcode                    int64
# Bedroom2                  float64
# Bathroom                  float64
# Car                       float64
# Landsize                  float64
# BuildingArea              float64
# YearBuilt                 float64
# CouncilArea                 int64
# Lattitude                 float64
# Longtitude                float64
# Regionname                  int64
# Propertycount             float64
# dtype: object
# ```
#
# All applicable numeric columns have been normalized, and categorical columns have been successfully converted to numerical types, preparing the dataset for further modeling.

# %% [markdown]
# ## Summarize Applied Transformations
#
# ### Subtask:
# Provide a summary of the normalization (StandardScaler on numeric columns) and transformation (LabelEncoder on categorical columns) steps that have already been applied to the DataFrame.

# %% [markdown]
# ## Summarize Applied Transformations
#
# ### Subtask:
# Provide a summary of the normalization (StandardScaler on numeric columns) and transformation (LabelEncoder on categorical columns) steps that have already been applied to the DataFrame.
#
# #### Instructions
# Write a summary detailing the normalization applied to numeric columns (Rooms, Price, Distance, Bedroom2, Bathroom, Car, Landsize, BuildingArea, YearBuilt, Lattitude, Longtitude, Propertycount) using StandardScaler, and the categorical encoding applied to categorical columns (Suburb, Address, Type, Method, SellerG, Postcode, CouncilArea, Regionname) using LabelEncoder. Also, mention the conversion of the 'Date' column to datetime objects and 'Postcode' to string before encoding.
#
# ### Summary of Applied Transformations:
#
# The following transformations have been applied to the DataFrame:
#
# 1.  **Date Column Conversion**: The 'Date' column was converted from an object type to `datetime` objects using `pd.to_datetime` with `dayfirst=True` to ensure correct parsing.
#
# 2.  **Postcode Column Conversion**: The 'Postcode' column, initially a float, was converted to a `string` type using `.astype(str)`. This was done to treat it as a categorical feature, making it suitable for subsequent label encoding.
#
# 3.  **Missing Value Imputation**:
#     *   **Numeric Columns**: Missing values in all numeric columns (identified by `df.select_dtypes(include=[np.number]).columns`) were imputed with the `mean` of their respective columns. This includes columns such as 'Car', 'BuildingArea', and 'YearBuilt'.
#     *   **Categorical Columns**: Missing values in the 'CouncilArea' categorical column were imputed with the `mode` (most frequent value) of that column.
#
# 4.  **Normalization of Numeric Features**: All numeric columns in the DataFrame were normalized using `StandardScaler`. This process rescales the data to have a mean of 0 and a standard deviation of 1, which helps in preparing the data for machine learning models that are sensitive to feature scales. The numeric columns include 'Rooms', 'Price', 'Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude', and 'Propertycount'.
#
# 5.  **Encoding of Categorical Features**: Categorical columns were transformed using `LabelEncoder`. This method converts each unique category in a column into an integer, allowing machine learning models to process these non-numeric features. The categorical columns that underwent this transformation include 'Suburb', 'Address', 'Type', 'Method', 'SellerG', 'Postcode', 'CouncilArea', and 'Regionname'.

# %% [markdown]
# **Reasoning**:
# The subtask requires displaying the first 5 rows of the `df` DataFrame to show the effect of the applied normalization and transformations. `df.head()` is the appropriate command for this.

# %%
df.head()
# Out:
#    Suburb  Address     Rooms  Type     Price  Method  SellerG       Date  \
# 0       0    12794 -0.981463     0  0.632448       1       23 2016-12-03
# 1       0     5943 -0.981463     0 -0.063640       1       23 2016-02-04
# 2       0     9814  0.064876     0  0.608984       3       23 2017-03-04
# 3       0     9004  0.064876     0 -0.353025       0       23 2017-03-04
# 4       0    10589  1.111216     0  0.820157       4      155 2016-06-04
#
#    Distance  Postcode  ...  Bathroom       Car  Landsize  BuildingArea  \
# 0 -1.301485        53  ... -0.772376 -0.635232 -0.089316      0.000000
# 1 -1.301485        53  ... -0.772376 -1.676467 -0.100843     -0.186147
# 2 -1.301485        53  ...  0.673367 -1.676467 -0.106356     -0.005020
# 3 -1.301485        53  ...  0.673367 -0.635232 -0.116380      0.000000
# 4 -1.301485        53  ... -0.772376  0.406003 -0.109864     -0.025428
#
#    YearBuilt  CouncilArea  Lattitude  Longtitude  Regionname  Propertycount
# ...

# %% [markdown]
# **Reasoning**:
# The previous `df.head()` command failed because the DataFrame `df` was not defined in the current execution context. To fix this, I need to regenerate all the preceding code cells that define and transform the `df` DataFrame, including data loading, type conversions, missing value imputation, normalization, and categorical encoding, before calling `df.head()` again.

# %% [markdown]
# **Reasoning**:
# The previous code failed with a `FileNotFoundError` because the specified CSV file was not found, likely due to Google Drive not being mounted in the Colab environment. To resolve this, I will add code to mount Google Drive before attempting to read the CSV file, which is a common practice in Colab when accessing files from Drive.

# %%
df["Date"] = pd.to_datetime(df["Date"], dayfirst = True)
df["Postcode"] = df["Postcode"].astype(str)

numeric_cols = df.select_dtypes(include=[np.number]).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

df["CouncilArea"] = df["CouncilArea"].fillna(df["CouncilArea"].mode()[0])

scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

categorical_cols = df.select_dtypes(include=["object"]).columns

encoder = LabelEncoder()
for col in categorical_cols:
    df[col] = encoder.fit_transform(df[col])

df.head()
# Out:
#      Suburb   Address     Rooms      Type     Price    Method   SellerG  \
# 0 -1.719825  1.582237 -0.981463 -0.632003  0.632448 -0.363956 -1.386938
# 1 -1.719825 -0.192832 -0.981463 -0.632003 -0.063640 -0.363956 -1.386938
# 2 -1.719825  0.810130  0.064876 -0.632003  0.608984  1.423252 -1.386938
# 3 -1.719825  0.600262  0.064876 -0.632003 -0.353025 -1.257560 -1.386938
# 4 -1.719825  1.010929  1.111216 -0.632003  0.820157  2.316857  0.311181
#
#         Date  Distance  Postcode  ...  Bathroom       Car  Landsize  \
# 0 2016-12-03 -1.301485       147  ... -0.772376 -0.635232 -0.089316
# 1 2016-02-04 -1.301485       147  ... -0.772376 -1.676467 -0.100843
# 2 2017-03-04 -1.301485       147  ...  0.673367 -1.676467 -0.106356
# 3 2017-03-04 -1.301485       147  ...  0.673367 -0.635232 -0.116380
# 4 2016-06-04 -1.301485       147  ... -0.772376  0.406003 -0.109864
#
#    BuildingArea     YearBuilt  CouncilArea  Lattitude  Longtitude  Regionname  \
# ...

# %% [markdown]
# **Reasoning**:
# The user has provided a comprehensive code block that includes mounting Google Drive, loading the data, performing all necessary transformations (date conversion, postcode conversion, missing value imputation, numeric scaling, and categorical encoding), and finally displaying the head of the transformed DataFrame. This directly addresses the subtask and previous errors.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, StandardScaler

from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Assignment_1/melb_data.csv")

df["Date"] = pd.to_datetime(df["Date"], dayfirst = True)
df["Postcode"] = df["Postcode"].astype(str)

numeric_cols = df.select_dtypes(include=[np.number]).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

df["CouncilArea"] = df["CouncilArea"].fillna(df["CouncilArea"].mode()[0])

scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

categorical_cols = df.select_dtypes(include=["object"]).columns

encoder = LabelEncoder()
for col in categorical_cols:
    df[col] = encoder.fit_transform(df[col])

df.head()
